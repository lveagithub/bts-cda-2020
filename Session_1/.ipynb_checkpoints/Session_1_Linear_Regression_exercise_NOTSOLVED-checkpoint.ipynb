# %% [markdown]
# ![BTS](https://github.com/vfp1/bts-dsf-2020/raw/main/Logo-BTS.jpg)
#
# # Session 1: Linear Regression Code Assignement
#
# ### Victor F. Pajuelo Madrigal <victor.pajuelo@bts.tech> - Classical Data Analysis (2020-12-21)
#
# Open this notebook in Google Colaboratory: [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vfp1/bts-cda-2020/blob/main/Session_1/Session_1_Linear_Regression_exercise_NOTSOLVED.ipynb)

# %% [markdown]
# An Ecommerce company sells clothing online but they also have in-store style and clothing advice sessions. Customers come in to the store, have sessions/meetings with a personal stylist, then they can go home and order either on a mobile app or website for the clothes they want. The company is trying to decide whether to focus their efforts on their mobile app experience or their website. They need our help to figure it out!
#
# **When working on the assignment there could be multiple models to explore data or iplement specific analysis. Choose that you retain more appropriate but always justify every choice you make (e.g., why you choose some variables), comment your code, describe the plots and results you obtain.**
#
# Feel free to add many cells as you need to write your code, comments, answers, etc.

# %% [markdown]
# ### Import libraries

# %%
#import matplotlib.pyplot as plt
#import seaborn as sns
#import numpy as np
#import pandas as pd
#from sklearn import datasets, linear_model
#from sklearn.metrics import mean_squared_error, r2_score
# %config IPCompleter.greedy=True
# %load_ext memory_profiler
# %matplotlib inline
# %run Session_1_Linear_Regression_exercise_NOTSOLVED_Helper.ipynb
# %run Session_1_Linear_Regression_exercise_NOTSOLVED_Plot.ipynb

# %% [markdown]
# #### Code to avoid cell auto-scrolling

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %% [markdown]
# #### Read the dataset provided by the company:
# They provide us with a csv file `Ecommerce_Customers.csv`

# %% [markdown]
# The dataset contains information about the customers:
#     - Email: email of the customer.
#     - Address: address of the customer.
#     - Avatar: color of the avatar.
#     - Avg. Session Length: Average session of in-store style advice sessions.
#     - Time on App: Average time spent on App in minutes
#     - Time on Website: Average time spent on Website in minutes
#     - Length of Membership: How many years the customer has been a member.

# %%
customers = pd.read_csv('Ecommerce_Customers.csv')
customers.head(3)
# Out:
#                        Email  \
# 0  mstephenson@fernandez.com
# 1          hduke@hotmail.com
# 2           pallen@yahoo.com
#
#                                              Address     Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605     Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576  DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...     Bisque
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505

# %%
# percentile list 
perc =[0.20, 0.40, 0.60, 0.80]
customers.describe(percentiles = perc)
#customers.describe()
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 20%              32.203883    11.202450        36.162370
# 40%              32.764381    11.772988        36.839798
# 50%              33.082008    11.983231        37.069367
# 60%              33.357484    12.294627        37.312895
# 80%              33.895757    12.955104        37.869564
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 20%                2.782110           434.119702
# 40%                3.315969           481.179778
# 50%                3.533975           498.887875
# 60%                3.787180           517.524905
# 80%                4.335814           560.751435
# max                6.922689           765.518462

# %% [markdown]
# ### Exploatory Data analysis

# %% [markdown]
# Perform some exploratory data analysis:
#     - Manual feature engineering. Is there any variable that do not make sense to take into account for your analysis? If yes, remove thos variables.
#     - Check for missing values
#     - check the distribution of the target variable to see if there is some outlier
#     - check which are the variables with highest correlation with the target variable
#     - check for multi-colinearity

# %% [markdown]
# **Manual feature engineering. Is there any variable that do not make sense to take into account for your analysis? If yes, explain why you think they are useless and remove them.**

# %% [markdown]
# Write your answer here:

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %% [markdown]
# <p style="border:2px solid DodgerBlue;">We select features according to the model we choose and the those that better explain the relationship between
# independents and target variables.
# In this case Email and Avatar are not contributing much to the model
# On the other hand, Address of the customer could be usable or interesting if we can get the geo points from the
# address and it would be event better if we had the physical store address so we can compute the distance
# as a brand new feature.
# unfortunaly, we don't have that feature in our dataset just now</p>

# %%
#Selecting the features
customers_features = customers[['Avg. Session Length', 
                           'Time on App', 
                           'Time on Website', 
                           'Length of Membership', 
                           'Yearly Amount Spent']]

# %%
#Checking memory usage and data types
customers_features.info(memory_usage='deep', verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5)
# memory usage: 19.6 KB

# %%
customers_features.head(3)
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
#
#    Yearly Amount Spent
# 0           587.951054
# 1           392.204933
# 2           487.547505

# %% [markdown]
# #### Check Missing values

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
cleaningHelper = CleaningHelper(version = "1.0")
print(cleaningHelper)
# Out:
# Cleaning helper version 1.0

# %%
#As pandas dataframe showed no null
cleaningHelper.get_nulls_data(customers_features)
# Out:
#                       Total  PercNotNull
# Yearly Amount Spent       0        100.0
# Length of Membership      0        100.0
# Time on Website           0        100.0
# Time on App               0        100.0
# Avg. Session Length       0        100.0

# %% [markdown]
# #### Check disttribution of the target variable

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
#Target variable
y = customers_features['Yearly Amount Spent']
type(y)
# Out:
# pandas.core.series.Series

# %%
df_= y
type_ = DisplotType.HIST
bins_ = 10
title_ = 'Target feature distribution - HIST'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %%
df_= y
type_ = DisplotType.KDE
bins_ = 10
title_ = 'Target feature distribution - KDE'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %%
df_= y
type_ = DisplotType.ECDF
bins_ = 10
title_ = 'Empirical distribution function - ECDF'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %%
#Just checking the normal distribution
print(stats.normaltest(y))
# Out:
# NormaltestResult(statistic=3.6517906683096006, pvalue=0.16107336506525619)

# %% [markdown]
# #### Check correlation among variables
#
# Explore the relation between each indipendent variable and the dipendent variable using multiple plots, among them also **jointplot** plots.

# %%
df_ = customers_features
title_ = 'Corrations'
ylabel_ = ''
height_ = 8
aspect_ = 11/8
custom_pairplot(df_, title_, ylabel_, height_, aspect_)

# %%
df_ = customers_features
title_ = 'Empirical distribution function - ECDF'
ylabel_ = ''
height_ = 8
aspect_ = 11/8
custom_heatmap(df_, title_, ylabel_, height_, aspect_)

# %% [markdown]
# <p style="border:2px solid DodgerBlue;">According to the analysis we can notice the strong corralation between
# "Length of Membership" and "Yearly Amount Spent"(target variable)</p>

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %% [markdown]
# ## Predictive model

# %% [markdown]
# Now that we have explored a bit the data we want to create a predictive model to understand if
# the company should focus more on their mobile app experience or on their website.
#
# Or maybe there is some other apsect that is still more important and and the company should focus on it!!
#
# Let's implement a simple linear regression model (choose the variable you reatin more appropriate and explain why you chose it) and a multivariate model that uses multiple variables.
#
# Then, based on your preliminary exploratoy data analysis and on the models' results draw your conclusion.

# %% [markdown]
# ### Simple linear regression

# %%
# Prepare data for training

#PUT YOUR CODE HERE

## Add further cells in case you need

# %% [markdown]
# ### Training and test splits
# Split the data into training and testing sets. We train the model with 75% of the samples and test with the remaining 25%. We do this to assess the model’s performance on unseen data. To split the data you may use ```scikit-learn library```. Finally print the sizes of our training and test set to verify if the splitting has occurred properly.
#
# **Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set random_state=5**

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
#Independent variable
#X = customers_features[['Length of Membership', 'Time on Website', 'Time on App', 'Avg. Session Length']]
X = customers_features[['Length of Membership']]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
#Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (375, 1)
# (125, 1)
# (375,)
# (125,)

# %% [markdown]
# ### Training of the model

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# %%
# Train the model using the training sets
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using the testing set
Y_pred = regr.predict(X_test)

# %% [markdown]
# #### Print the coeficients of the model

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %% [markdown]
# ### Make a plot to show how the model fit the training data.
#
# Looking at the plot explain if the coefficients you found make sense

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
# Plot outputs
plt.scatter(X_test, Y_test,  color='black')
plt.plot(X_test, Y_pred, color='blue', linewidth=3)

#plt.xticks(())
#plt.yticks(())

plt.show()

# %%
#customers_pred = pd.DataFrame()
#customers_pred = X_test
#customers_pred.head(3)

# %%
#g = sns.FacetGrid(customers_pred, height = 10)
#g = g.map(plt.scatter, 'Length of Membership', 'Y_test', edgecolor="w")
#plt.plot(customers_features['Yearly Amount Spent'], slr_slope*customers_features['Yearly Amount Spent'] + slr_intercept, color = 'r', linewidth = 2)

# %%
df_= Y_pred
type_ = DisplotType.KDE
bins_ = 10
title_ = 'Prediction feature distribution - KDE'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %% [markdown]
# ### Evaluate the model on the test set
#
#     - Make some plots you think maybe usefull to evaluate the predictions of our model and then evaluate it through some metrics.

# %%
df_= y
type_ = DisplotType.HIST
bins_ = 10
title_ = 'Target feature distribution - HIST'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %% [markdown]
# #### Evalution Metrics

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f' % metrics.mean_squared_error(Y_test, Y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f' % metrics.r2_score(Y_test, Y_pred))
# Out:
# Coefficients:
#  [64.70352335]
# Mean squared error: 2093.29
# Coefficient of determination: 0.62

# %%
#from sklearn import metrics
print('MAE= ', metrics.mean_absolute_error(Y_test,Y_pred))
print('MSE= ', metrics.mean_squared_error(Y_test,Y_pred))
print('RMSE= ', np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
# Out:
# MAE=  36.906874929496865
# MSE=  2093.2889570502084
# RMSE=  45.75247487349956

# %%
metrics.explained_variance_score(Y_test,Y_pred)
# Out:
# 0.6171960754523832

# %%
# Exploring the residuals to make sure that everything was okay

# %%
df_= Y_test - Y_pred
type_ = DisplotType.HIST
bins_ = 10
title_ = 'Prediction distribution - HIST'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %%
df_= Y_test - Y_pred
type_ = DisplotType.KDE
bins_ = 10
title_ = 'Prediction distribution - KDE'
ylabel_ = 'Density'
height_ = 8
aspect_ = 11/8
custom_displot_one_feature(df_, type_, bins_, title_, ylabel_, height_, aspect_)

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %% [markdown]
# ## Multivariate Model

# %%
# Prepare data for training

#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
#Independent variables
#X = customers_features[['Length of Membership', 'Time on Website', 'Time on App', 'Avg. Session Length']]
X = customers_features[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership']]
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
X.head(3)
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543

# %%
#Target variable
y = customers_features['Yearly Amount Spent']
type(y)
# Out:
# pandas.core.series.Series

# %%
y.head(3)
# Out:
# 0    587.951054
# 1    392.204933
# 2    487.547505
# Name: Yearly Amount Spent, dtype: float64

# %% [markdown]
# ### Training and test splits
# Next, we split the data into training and testing sets. We train the model with 75% of the samples and test with the remaining 25%. We do this to assess the model’s performance on unseen data. To split the data you may use ```scikit-learn library```. Finally print the sizes of our training and test set to verify if the splitting has occurred properly.
#
# **Use model_selection.train_test_split from sklearn to split the data into training and testing sets. Set random_state=5**

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
#Train-test split
X_train, X_test, Y_train, Y_test = train_test_split(X,y,test_size=0.25,random_state=42)
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (375, 4)
# (125, 4)
# (375,)
# (125,)

# %% [markdown]
# ### Training of the model

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
# Create linear regression object
regr = linear_model.LinearRegression()

# %%
# Train the model using the training sets
regr.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# Make predictions using the testing set
Y_pred = regr.predict(X_test)

# %%
sns.regplot(x=Y_test, y=Y_pred, ci=None, color="b")

# %% [markdown]
# #### Print the coeficients of the model

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %% [markdown]
# ### Evaluate the model on the test set
#
#     - Make some plots you think maybe usefull to evaluate the predictions of our model and then evaluate it through some metrics.

# %% [markdown]
# #### Evalution Metrics

# %%
#PUT YOUR CODE HERE

## Add further cells in case you need

# %%
# The coefficients
print('Coefficients: \n', regr.coef_)
# The mean squared error
print('Mean squared error: %.2f' % metrics.mean_squared_error(Y_test, Y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f' % metrics.r2_score(Y_test, Y_pred))
# Out:
# Coefficients:
#  [25.69083176 38.68815596  0.45279908 61.71050259]
# Mean squared error: 105.65
# Coefficient of determination: 0.98

# %%
#from sklearn import metrics
print('MAE= ', metrics.mean_absolute_error(Y_test,Y_pred))
print('MSE= ', metrics.mean_squared_error(Y_test,Y_pred))
print('RMSE= ', np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
# Out:
# MAE=  8.460454170141151
# MSE=  105.64514296279508
# RMSE=  10.278382312542917

# %%
metrics.explained_variance_score(Y_test,Y_pred)
# Out:
# 0.9808730259915573

# %%
regr.predict([[1,2,3,4]])
# Out:
# array([-699.43983675])

# %%
#regr.coef_

# %%
#Printing the coefficients
cdf=pd.DataFrame(regr.coef_,X.columns,columns=['Coeff'] )
cdf
# Out:
#                           Coeff
# Avg. Session Length   25.690832
# Time on App           38.688156
# Time on Website        0.452799
# Length of Membership  61.710503

# %%
#Multiple variables plotting
fig, axes = plt.subplots(1,len(customers_features.columns.values),sharey=True,constrained_layout=True,figsize=(30,15))

for i,e in enumerate(customers_features.columns):
    regr.fit(customers_features[e].values[:,np.newaxis], y.values)
    axes[i].set_title("Best fit line")
    axes[i].set_xlabel(str(e))
    axes[i].set_ylabel('SalePrice')
    axes[i].scatter(customers_features[e].values[:,np.newaxis], y,color='b')
    axes[i].plot(customers_features[e].values[:,np.newaxis], 
    regr.predict(customers_features[e].values[:,np.newaxis]),color='k')

# %% [markdown]
# #### Which model has better performance?

# %% [markdown]
# Write your answer here:

# %% [markdown]
# <p style="border:2px solid DodgerBlue;">According to the metrics can stand the Multivariate Model is better than Simple regression Model.
# </p>

# %% [markdown]
# **Describe how you interpret the coefficients of the model and based on that decide how the company shoud behave in order to try to improve their business increasing the `Yearly Amount Spent` per customenr.**

# %% [markdown]
# Write your answer here:

# %% [markdown]
# <p style="border:2px solid DodgerBlue;">According to the analysis of the coefficients we can deduce that the largest increase of 'Yearly Amount Spent' can be observed when the feature 'Length of Membership' is increased by one unit (61.710503).<br> Also, we noticed the importance of the feature "Time on App" but, we can advice to the company the necessity of focusing on the website and increase the 'Avg. Session Length'.
# </p>
